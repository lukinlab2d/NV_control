# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import time
import os
from scipy.optimize import curve_fit
import B00_codes.dataReader as dr
import matplotlib.colors as colors

NO_MS_EQUALS_1 = 0
Q_FINAL = 1
THREE_PI_HALF_FINAL = 2
REF_MINUS_SIG  =3

# %%
dataFilename = 'C:/Users/lukin2dmaterials/data/2023-05-26/#002_Live_counter_03-31-07/time_s_set.dat'

iter, sig = dr.readDataLiveCounter(dataFilename, figsize=(100,2), acqTimeMs = 50, correctionFactor=2.7)

# %%
dataFilename = 'C:/Users/lukin2dmaterials/data/2023-05-26/#003_Live_counter_11-20-19/time_s_set.dat'

iter, sig = dr.readDataLiveCounter(dataFilename, figsize=(100,2), acqTimeMs = 30, correctionFactor=3.85)
